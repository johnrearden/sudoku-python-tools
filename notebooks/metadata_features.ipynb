# %% [markdown]
# # Notebook Outline
#
# In this notebook, puzzle generation history is loaded from csv file and new features are generated from the puzzle metadata.

# %%
import numpy as np
import pandas as pd

# %%
import os
current_dir = os.getcwd()
os.chdir(os.path.dirname(current_dir))
current_dir = os.getcwd()
current_dir
# Out:
# '/home/john/dev'

# %%
os.chdir('/home/john/dev/sudoku-python-tools')

# %%
df = pd.read_csv('inputs/csv_files/40_knowns_rib.csv')
df.head(3)
len(df)
# Out:
# 784

# %% [markdown]
# Let's create a new feature - missing_digit_count. We can calculate it for each row by applying a function.

# %%
def missing_digits_count(puzzle_string):
    missing_digits = [n for n in range(1, 10) if str(n) not in puzzle_string]
    return len(missing_digits)

df['missing_digit_count'] = df['puzzle_string'].apply(missing_digits_count) 
df.head(3)
# Out:
#    known_count  unique_solution  \
# 0           40            False
# 1           40            False
# 2           40             True
#
#                                        puzzle_string  time_taken  \
# 0  -8962---44--9---2871---4--689---5-12-56--27--2...        0.01
# 1  729---316------72-316972--4----9-2472--4--961-...        0.02
# 2  --79---24--37----92-94-3---7-413-6--82--941-33...        0.04
#
#    missing_digit_count
# 0                    0
# 1                    2
# 2                    0

# %% [markdown]
# Other useful features might be the number of empty nonets and the standard deviation of the count of known_cells in each nonet also.

# %%
from tools.constants import nonets

def empty_nonets_count(puzzle_string):
    ps = puzzle_string
    empty_nonets_count = 0
    for nonet in nonets:
        cells = [ps[idx] for idx in nonet if ps[idx] != '-']
        if not cells:
            empty_nonets_count += 1
    return empty_nonets_count

df['empty_nonets_count'] = df['puzzle_string'].apply(empty_nonets_count)
len(df[(df['empty_nonets_count'] > 0)])
# Out:
# 18

# %%
from statistics import pstdev

def stddev_nonets_population(puzzle_string):
    ps = puzzle_string
    population_list = []
    for nonet in nonets:
        cells = [int(ps[idx]) for idx in nonet if ps[idx] != '-']
        population_list.append(len(cells))
    return pstdev(population_list)

df['stddev_nonet_population'] = df['puzzle_string'].apply(stddev_nonets_population)
df.head(3)
# Out:
#    known_count  unique_solution  \
# 0           40            False
# 1           40            False
# 2           40             True
#
#                                        puzzle_string  time_taken  \
# 0  -8962---44--9---2871---4--689---5-12-56--27--2...        0.01
# 1  729---316------72-316972--4----9-2472--4--961-...        0.02
# 2  --79---24--37----92-94-3---7-413-6--82--941-33...        0.04
#
#    missing_digit_count  empty_nonets_count  stddev_nonet_population
# 0                    0                   0                 1.030402
# 1                    2                   0                 1.685083
# 2                    0                   0                 1.257079

# %% [markdown]
# Try adding the min, mean, stddev and max digit count

# %%
from collections import defaultdict
from statistics import fmean, pstdev

def get_digit_counts(puzzle_string):
    counts = defaultdict(int)
    for char in puzzle_string:
        if char.isnumeric():
            counts[int(char)] += 1
    return counts

def get_min_digit_count(puzzle_string):
    counts = get_digit_counts(puzzle_string)
    return min(counts.values())

def get_mean_digit_count(puzzle_string):
    counts = get_digit_counts(puzzle_string)
    return fmean(counts.values())

def get_stddev_digit_count(puzzle_string):
    counts = get_digit_counts(puzzle_string)
    return pstdev(counts.values())

def get_max_digit_count(puzzle_string):
    counts = get_digit_counts(puzzle_string)
    return max(counts.values())



df['min_digit_count'] = df['puzzle_string'].apply(get_min_digit_count)
df['mean_digit_count'] = df['puzzle_string'].apply(get_mean_digit_count)
df['stddev_digit_count'] = df['puzzle_string'].apply(get_stddev_digit_count)
df['max_digit_count'] = df['puzzle_string'].apply(get_max_digit_count)
df.head(3)
# Out:
#    known_count  unique_solution  \
# 0           40            False
# 1           40            False
# 2           40             True
#
#                                        puzzle_string  time_taken  \
# 0  -8962---44--9---2871---4--689---5-12-56--27--2...        0.01
# 1  729---316------72-316972--4----9-2472--4--961-...        0.02
# 2  --79---24--37----92-94-3---7-413-6--82--941-33...        0.04
#
#    missing_digit_count  empty_nonets_count  stddev_nonet_population  \
# 0                    0                   0                 1.030402
# 1                    2                   0                 1.685083
# 2                    0                   0                 1.257079
#
#    min_digit_count  mean_digit_count  stddev_digit_count  max_digit_count
# 0                1          4.444444            2.006163                8
# 1                5          5.714286            0.699854                7
# 2                1          4.444444            2.114033                8

# %% [markdown]
# Try adding features for each nonet.

# %%
def get_nonet_pop_per_nonet(puzzle_string, nonet_index):
    ps = str(puzzle_string)
    count = 0
    for index in nonets[nonet_index]:
        if ps[index].isnumeric():
            count += 1
    return count
    
nonet_types = ['row', 'col', 'sqr']
for idx in range(27):
    nonet_type = nonet_types[idx // 9]
    nonet_id = idx % 9
    df[f'{nonet_type}_{nonet_id}'] = df['puzzle_string'].apply(get_nonet_pop_per_nonet, args=(idx,))

# %% [markdown]
# ### Drop the puzzle_string column before correlation analysis

# %%
df.drop(['puzzle_string'], axis=1, inplace=True)
df.head(20)
# Out:
#     known_count  unique_solution  time_taken  missing_digit_count  \
# 0            40            False        0.01                    0
# 1            40            False        0.02                    2
# 2            40             True        0.04                    0
# 3            40            False        0.01                    0
# 4            40            False        0.03                    1
# 5            40            False        0.03                    0
# 6            40            False        0.04                    0
# 7            40            False        0.05                    0
# 8            40            False        0.07                    1
# 9            40             True        0.09                    0
# 10           40            False        0.01                    0
# 11           40            False        0.03                    1
# 12           40            False        0.04                    0
# 13           40            False        0.05                    1
# 14           40            False        0.07                    1
# 15           40            False        0.08                    0
# 16           40            False        0.11                    1
# 17           40            False        0.11                    1
# 18           40             True        0.13                    1
# 19           40             True        0.01                    0
#
#     empty_nonets_count  stddev_nonet_population  min_digit_count  \
# 0                    0                 1.030402                1
# 1                    0                 1.685083                5
# 2                    0                 1.257079                1
# 3                    0                 1.422916                1
# 4                    0                 1.448712                2
# 5                    0                 1.594744                1
# 6                    0                 1.257079                2
# 7                    0                 0.955814                2
# 8                    0                 1.227262                3
# 9                    0                 1.523479                1
# 10                   0                 1.396645                1
# 11                   0                 1.099944                2
# 12                   0                 1.422916                2
# 13                   0                 1.133115                2
# 14                   0                 1.196703                2
# 15                   0                 1.448712                1
# 16                   0                 1.662959                3
# 17                   0                 1.030402                3
# 18                   0                 1.474055                3
# 19                   0                 1.196703                2
#
#     mean_digit_count  stddev_digit_count  max_digit_count  ...  col_8  sqr_0  \
# 0           4.444444            2.006163                8  ...      7      5
# 1           5.714286            0.699854                7  ...      6      6
# 2           4.444444            2.114033                8  ...      5      4
# 3           4.444444            2.266231                7  ...      4      4
# 4           5.000000            1.500000                7  ...      6      5
# 5           4.444444            1.571348                7  ...      2      2
# 6           4.444444            1.571348                7  ...      3      4
# 7           4.444444            2.006163                8  ...      3      4
# 8           5.000000            1.500000                8  ...      3      4
# 9           4.444444            1.640536                6  ...      1      4
# 10          4.444444            2.165954                7  ...      7      4
# 11          5.000000            1.658312                8  ...      4      4
# 12          4.444444            2.060804                8  ...      3      6
# 13          5.000000            1.581139                7  ...      5      4
# 14          5.000000            1.414214                7  ...      4      3
# 15          4.444444            1.949992                8  ...      2      5
# 16          5.000000            1.322876                7  ...      6      5
# 17          5.000000            1.658312                8  ...      4      6
# 18          5.000000            1.000000                6  ...      5      4
# 19          4.444444            1.257079                6  ...      3      4
#
#     sqr_1  sqr_2  sqr_3  sqr_4  sqr_5  sqr_6  sqr_7  sqr_8
# 0       4      4      5      3      5      4      5      5
# 1       3      6      2      3      7      2      5      6
# 2       4      3      5      6      5      2      5      6
# 3       4      6      7      5      3      6      1      4
# 4       4      4      6      4      8      2      4      3
# 5       6      2      5      6      7      5      5      2
# 6       5      4      6      5      4      6      2      4
# 7       4      3      4      5      5      5      4      6
# 8       4      3      7      5      4      2      7      4
# 9       3      4      3      4      4      8      5      5
# 10      3      5      4      3      5      5      5      6
# 11      4      5      3      5      5      4      7      3
# 12      5      5      4      5      5      5      2      3
# 13      5      6      4      3      5      6      3      4
# 14      3      4      7      4      3      4      7      5
# 15      3      3      6      5      5      3      6      4
# 16      1      6      7      3      5      7      3      3
# 17      4      5      2      5      5      4      5      4
# 18      3      2      5      3      7      3      6      7
# 19      3      4      3      6      4      6      5      5
#
# [20 rows x 37 columns]

# %% [markdown]
# ### Run correlation analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 784 entries, 0 to 783
# Data columns (total 37 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   known_count              784 non-null    int64
#  1   unique_solution          784 non-null    bool
#  2   time_taken               784 non-null    float64
#  3   missing_digit_count      784 non-null    int64
#  4   empty_nonets_count       784 non-null    int64
#  5   stddev_nonet_population  784 non-null    float64
#  6   min_digit_count          784 non-null    int64
#  7   mean_digit_count         784 non-null    float64
#  8   stddev_digit_count       784 non-null    float64
#  9   max_digit_count          784 non-null    int64
#  10  row_0                    784 non-null    int64
#  11  row_1                    784 non-null    int64
#  12  row_2                    784 non-null    int64
#  13  row_3                    784 non-null    int64
#  14  row_4                    784 non-null    int64
#  15  row_5                    784 non-null    int64
#  16  row_6                    784 non-null    int64
#  17  row_7                    784 non-null    int64
#  18  row_8                    784 non-null    int64
#  19  col_0                    784 non-null    int64
#  20  col_1                    784 non-null    int64
#  21  col_2                    784 non-null    int64
#  22  col_3                    784 non-null    int64
#  23  col_4                    784 non-null    int64
#  24  col_5                    784 non-null    int64
#  25  col_6                    784 non-null    int64
#  26  col_7                    784 non-null    int64
#  27  col_8                    784 non-null    int64
#  28  sqr_0                    784 non-null    int64
#  29  sqr_1                    784 non-null    int64
#  30  sqr_2                    784 non-null    int64
#  31  sqr_3                    784 non-null    int64
#  32  sqr_4                    784 non-null    int64
#  33  sqr_5                    784 non-null    int64
#  34  sqr_6                    784 non-null    int64
#  35  sqr_7                    784 non-null    int64
#  36  sqr_8                    784 non-null    int64
# dtypes: bool(1), float64(4), int64(32)
# memory usage: 221.4 KB

# %%
corr_spearman = df.corr(method='spearman')['unique_solution'].sort_values(key=abs, ascending=False)[1:]
corr_spearman
# Out:
# stddev_digit_count        -0.161982
# max_digit_count           -0.155649
# missing_digit_count       -0.101093
# mean_digit_count          -0.101093
# stddev_nonet_population   -0.072933
# row_7                      0.072325
# sqr_7                      0.064712
# col_2                      0.063535
# sqr_3                      0.051505
# min_digit_count            0.049926
# col_1                     -0.049410
# col_4                      0.048492
# sqr_0                     -0.048471
# time_taken                 0.047675
# col_7                     -0.043478
# row_1                     -0.042980
# sqr_5                     -0.039206
# sqr_6                      0.026714
# col_5                      0.024519
# sqr_8                     -0.023709
# row_0                      0.022971
# col_8                     -0.021021
# row_6                     -0.020330
# row_2                     -0.019880
# col_0                      0.019009
# row_8                      0.017143
# row_3                     -0.015077
# col_6                     -0.013261
# row_4                      0.012740
# empty_nonets_count        -0.011562
# sqr_1                      0.008087
# sqr_4                      0.003614
# col_3                      0.001410
# sqr_2                      0.000497
# row_5                      0.000444
# known_count                     NaN
# Name: unique_solution, dtype: float64

# %%
corr_pearson = df.corr(method='pearson')['unique_solution'].sort_values(key=abs, ascending=False)[1:]
corr_pearson
# Out:
# stddev_digit_count        -0.162026
# max_digit_count           -0.143814
# mean_digit_count          -0.104541
# missing_digit_count       -0.103814
# stddev_nonet_population   -0.082249
# sqr_0                     -0.061838
# time_taken                 0.060816
# row_7                      0.058786
# sqr_7                      0.057349
# col_1                     -0.055875
# Name: unique_solution, dtype: float64
